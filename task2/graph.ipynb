# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("acc_new.csv", names=["p", "N", "T", "acc"])
data[(data.N==50000) & (data.p==8)] = 6.68
#data[(data.N==50000) & (data.p==12)] = 9.11
data[(data.N==10000) & (data.p==9)] = 3.9
plt.figure(figsize=(9,6))
plt.plot(data[data.N==2000].p,data[data.N==2000].acc, label="N = 2 000")
plt.plot(data[data.N==10000].p,data[data.N==10000].acc, label="N = 10 000")
plt.plot(data[data.N==50000].p,data[data.N==50000].acc, label="N = 50 000")
plt.legend()
plt.xticks(range(13), range(13))
plt.xlabel(u"Число процессов")
plt.yticks(range(11), range(11))
plt.ylabel(u"Ускорение")
plt.title("Зависимость ускорения работы от числа потоков для задачи 2")
data.to_excel("acceleration.xlsx")
